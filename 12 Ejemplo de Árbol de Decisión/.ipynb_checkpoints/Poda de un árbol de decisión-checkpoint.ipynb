# %% [markdown]
# # Poda de un árbol de decisión

# %% [markdown]
# Importamos las bibliotecas necesarias

# %%
import pandas            as pd    # Biblioteca para trabajar con DataFrames
import numpy             as np    # Biblioteca para trabajar con àlgebra lineal
import matplotlib.pyplot as plt   # Biblioteca para realizar gràficas
from sklearn.metrics         import accuracy_score, confusion_matrix   # Funciones para medir la precisión
from sklearn.model_selection import cross_val_score                    # Funciones para selección de modelos
from sklearn.tree            import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree # Funciones de clase Tree
# https://scikit-learn.org/stable/modules/tree.html
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Leemos el archivo `iris.csv`

# %%
print("Vista previa del dataset:")
datos_iris = pd.read_csv("iris.csv")
datos_iris.head()
# Out:
# Vista previa del dataset:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Información general del dataset.
# Tipo de dato de cada variable, las dimensiones de la tabla, así como el tamaño en memoria

# %% [markdown]
# Separamos nuestras variables explicativas y nuestra variable respuesta. Entrenamos nuestro modelo.

# %% [markdown]
# Resumen de cada variable

# %%
# Datos para realizar el ajuste
matriz_diseño = datos_iris.values[:,0:4]
y_real        = datos_iris.values[:,4]

print("Matriz de Diseño:")
print(matriz_diseño[0:5,:])
print("")
print("Y Real")
print(y_real[0:5])
# Out:
# Matriz de Diseño:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]]
#
# Y Real
# ['setosa' 'setosa' 'setosa' 'setosa' 'setosa']

# %% [markdown]
# ### Modelo Inicial
#
# Ajustamos nuestro modelo de árbol de decisión con los parámetros de defecto.
#
# Unicamente colocamos una semilla `(random_state)` para replicar los resultados, graficamos nuestro árbol.
#
# Estimamos nuestra variable respuesta y posteriormente medimos la precisión del modelo

# %%
modelo_arbol = DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None, max_features=None,
                max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1,
                min_samples_split=2, min_weight_fraction_leaf=0.0, presort=False, random_state=0, splitter='best')
modelo_arbol.fit(matriz_diseño, y_real)
modelo_arbol

# Graficamos el arbol
plt.figure( figsize=(16,8) )                                      # Indicamos el tamaño de la gráfica
plot_tree(modelo_arbol, filled=True, rounded=True, precision=2 )  # Graficamos el árbol de decisión 
plt.show()                                                        # Indicamos que queremos mostrar la gráfica

# Precisión por Validación Cruzada
print( "Precisión CV :: ", np.mean( cross_val_score( estimator = modelo_arbol, X = matriz_diseño, y = y_real, cv = 10) ) )
# Out:
# Precisión CV ::  0.96

# %% [markdown]
# ### Modificando `(criterion)`
#
# Criterio de división en cada iteración.

# %%
modelo_arbol = DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None, max_features=None,
                max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1,
                min_samples_split=2, min_weight_fraction_leaf=0.0, presort=False, random_state=0, splitter='best')
modelo_arbol.fit(matriz_diseño, y_real)
modelo_arbol

# Graficamos el arbol
plt.figure( figsize=(16,8) )                                      # Indicamos el tamaño de la gráfica
plot_tree(modelo_arbol, filled=True, rounded=True, precision=2 )  # Graficamos el árbol de decisión 
plt.show()                                                        # Indicamos que queremos mostrar la gráfica

# Precisión por Validación Cruzada
print( "Precisión CV :: ", np.mean( cross_val_score( estimator = modelo_arbol, X = matriz_diseño, y = y_real, cv = 10) ) )
# Out:
# Precisión CV ::  0.96

# %% [markdown]
# ### Modificando `(min_samples_leaf)`
#
# Número mínimo de muestras que debe tener una hoja (nodo final)

# %%
modelo_arbol = DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None, max_features=None,
                max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=8,
                min_samples_split=2, min_weight_fraction_leaf=0.0, presort=False, random_state=0, splitter='best')
modelo_arbol.fit(matriz_diseño, y_real)
modelo_arbol

# Graficamos el arbol
plt.figure( figsize=(16,8) )                                      # Indicamos el tamaño de la gráfica
plot_tree(modelo_arbol, filled=True, rounded=True, precision=2 )  # Graficamos el árbol de decisión 
plt.show()                                                        # Indicamos que queremos mostrar la gráfica

# Precisión por Validación Cruzada
print( "Precisión CV :: ", np.mean( cross_val_score( estimator = modelo_arbol, X = matriz_diseño, y = y_real, cv = 10) ) )
# Out:
# Precisión CV ::  0.9533333333333334

# %% [markdown]
# ### Modificando `(max_depth)`
#
# Cantidad de niveles / pisos en el árbol.

# %%
modelo_arbol = DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3, max_features=None,
                max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1,
                min_samples_split=2, min_weight_fraction_leaf=0.0, presort=False, random_state=0, splitter='best')
modelo_arbol.fit(matriz_diseño, y_real)
modelo_arbol

# Graficamos el arbol
plt.figure( figsize=(16,8) )                                      # Indicamos el tamaño de la gráfica
plot_tree(modelo_arbol, filled=True, rounded=True, precision=2 )  # Graficamos el árbol de decisión 
plt.show()                                                        # Indicamos que queremos mostrar la gráfica

# Precisión por Validación Cruzada
print( "Precisión CV :: ", np.mean( cross_val_score( estimator = modelo_arbol, X = matriz_diseño, y = y_real, cv = 10) ) )
# Out:
# Precisión CV ::  0.96

# %% [markdown]
# ### Modificando `(max_features)`
#
# Número de covariables / columnas que considera para cada árbol generado en cada iteración.

# %%
modelo_arbol = DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None, max_features=2,
                max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1,
                min_samples_split=2, min_weight_fraction_leaf=0.0, presort=False, random_state=0, splitter='best')
modelo_arbol.fit(matriz_diseño, y_real)
modelo_arbol

# Graficamos el arbol
plt.figure( figsize=(16,8) )                                      # Indicamos el tamaño de la gráfica
plot_tree(modelo_arbol, filled=True, rounded=True, precision=2 )  # Graficamos el árbol de decisión 
plt.show()                                                        # Indicamos que queremos mostrar la gráfica

# Precisión por Validación Cruzada
print( "Precisión CV :: ", np.mean( cross_val_score( estimator = modelo_arbol, X = matriz_diseño, y = y_real, cv = 10) ) )
# Out:
# Precisión CV ::  0.9533333333333334

# %% [markdown]
# ### Modificando `(max_leaf_nodes)`
#
# Número máximo de hojas (nodos finales)

# %%
modelo_arbol = DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None, max_features=None,
                max_leaf_nodes=4, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1,
                min_samples_split=2, min_weight_fraction_leaf=0.0, presort=False, random_state=0, splitter='best')
modelo_arbol.fit(matriz_diseño, y_real)
modelo_arbol

# Graficamos el arbol
plt.figure( figsize=(16,8) )                                      # Indicamos el tamaño de la gráfica
plot_tree(modelo_arbol, filled=True, rounded=True, precision=2 )  # Graficamos el árbol de decisión 
plt.show()                                                        # Indicamos que queremos mostrar la gráfica

# Precisión por Validación Cruzada
print( "Precisión CV :: ", np.mean( cross_val_score( estimator = modelo_arbol, X = matriz_diseño, y = y_real, cv = 10) ) )
# Out:
# Precisión CV ::  0.9666666666666666
